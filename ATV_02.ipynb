# %% [markdown]
# <a href="https://colab.research.google.com/github/caiosemblano/M06-Lab-Estatistica/blob/main/ATV_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Nome: Caio Semblano Silva
#
# ## Matrícula: 621

# %% [markdown]
# ---

# %% [markdown]
# # Atividade 2 - Algoritmos e Métodos Numéricos, Erros, Medidas e Fontes

# %% [markdown]
# Uma equipe de desenvolvedores e engenheiros está projetando um sistema de monitoramento térmico em tempo real para as CPUs de um Data Center. O objetivo do sistema é acionar o resfriamento de emergência sempre que a temperatura da CPU atingir o limite crítico de segurança, definido como $85\text{ }^\circ\text{C}$ por um sensor óptico padrão de calibração de altíssima precisão.
# Para baratear o custo, a equipe testou 6 módulos de sensores de temperatura IoT diferentes (série de nós de sensores $S_1$ a $S_6$). Devido a limitações de hardware — como a resolução do Conversor Analógico-Digital (ADC) do microcontrolador (erro de quantização e truncamento), ruído eletromagnético e tolerância dos componentes —, os valores digitais lidos por cada sensor apresentaram pequenas divergências em relação ao valor real de referência.
#
#
#
# Os resultados dos sensores estão na tabela abaixo:
#
# | Módulo de Sensor | Temperatura Lida (°C) |
# | --- | --- |
# | Sensor S1 | 84,820 |
# | Sensor S2 | 85,150 |
# | Sensor S3 | 84,985 |
# | Sensor S4 | 85,040 |
# | Sensor S5 | 85,310 |
# | Sensor S6 | 84,910 |
#
#
# Seu objetivo é analisar esses dados e calcular diferentes métricas de erro, usando as bibliotecas pandas e numpy.
#
# ---

# %%
from IPython.display import display
# Importando bibliotecas

#Analise de dados
import pandas as pd
import numpy as np

# %%
Valor_referencia = 85
#Tabela de dados
tabela = {
    "Sensor": [
        "Sensor S1",
        "Sensor S2",
        "Sensor S3",
        "Sensor S4",
        "Sensor S5",
        "Sensor S6",
    ],
    "Temp_Lida (°C)": [84.820, 85.150, 84.985, 85.040, 85.310, 84.910],
}

dados = pd.DataFrame(tabela)
display(dados)
# Out:
#       Sensor  Temp_Lida (°C)
# 0  Sensor S1          84.820
# 1  Sensor S2          85.150
# 2  Sensor S3          84.985
# 3  Sensor S4          85.040
# 4  Sensor S5          85.310
# 5  Sensor S6          84.910

# %% [markdown]
# ### Parte 1 - Erro Absoluto, Erro Relativo e Erro Percentual

# %% [markdown]
# Calcule o Erro Absoluto, o Erro Relativo e o Erro Percentual dos valores medidos.

# %%
dados["Erro Absoluto"] = abs(dados["Temp_Lida (°C)"] - Valor_referencia)
dados["Erro Relativo"] = dados["Erro Absoluto"] / abs(dados["Temp_Lida (°C)"])
dados["Erro Percentual"] = dados["Erro Relativo"] * 100
display(dados)
# Out:
#       Sensor  Temp_Lida (°C)  Erro Absoluto  Erro Relativo  Erro Percentual
# 0  Sensor S1          84.820          0.180       0.002122         0.212214
# 1  Sensor S2          85.150          0.150       0.001762         0.176160
# 2  Sensor S3          84.985          0.015       0.000177         0.017650
# 3  Sensor S4          85.040          0.040       0.000470         0.047037
# 4  Sensor S5          85.310          0.310       0.003634         0.363381
# 5  Sensor S6          84.910          0.090       0.001060         0.105995

# %% [markdown]
# **Formulário para cálculo de erros**
#
# - Erro Absoluto:
# $$E_a = |V_t - V_m|$$
#
# - Erro Relativo:
# $$E_r = \frac{E_a}{|V_m|}$$
#
# - Erro Percentual:
# $$E_p = E_r \times 100\%$$
#
# Onde:
# - $V_t$ = valor teórico de referência
# - $V_m$ = valor medido pelo sensor

# %% [markdown]
# ### Parte 2 - Arredondamento e Truncamento

# %% [markdown]
# Um engenheiro biomédico está testando um novo sensor para um oxímetro de pulso hospitalar (aparelho que mede a saturação de oxigênio no sangue, $SpO_2$).
#
# O sensor faz a medição com alta precisão (quatro casas decimais), mas o visor do aparelho só tem espaço para mostrar o número arredondado com duas casas decimais.
#
# As medições feitas pelo sensor em cinco pacientes foram:

# %% [markdown]
# | Paciente | Oxigênio Medido (%) |
# | --- | --- |
# | P1 | 92.3456 |
# | P2 | 98.8765 |
# | P3 | 95.5555 |
# | P4 | 97.4999 |
# | P5 | 90.0501 |

# %% [markdown]
# ### 1 - Fazer um DataFrame para organização visual dos dados

# %%
table = {
    "Paciente": ["P1", "P2", "P3", "P4", "P5"],
    "Oxigênio Medido (%)": [92.3456, 98.8765, 95.5555, 97.4999, 90.0501],
}
dados = pd.DataFrame(table)
display(dados)
# Out:
#   Paciente  Oxigênio Medido (%)
# 0       P1              92.3456
# 1       P2              98.8765
# 2       P3              95.5555
# 3       P4              97.4999
# 4       P5              90.0501

# %% [markdown]
# ### 2 - Arredonde todos os valores para 2 casas decimais

# %%
dados["Oxigênio Medido (%)"] = dados["Oxigênio Medido (%)"].round(2)
display(dados)
# Out:
#   Paciente  Oxigênio Medido (%)
# 0       P1                92.35
# 1       P2                98.88
# 2       P3                95.56
# 3       P4                97.50
# 4       P5                90.05

# %% [markdown]
# ### 3 - Trunque os valores para 1 casa decimal

# %%
dados["Oxigênio Medido (%)"] = np.trunc(dados["Oxigênio Medido (%)"] * 10)/10
display(dados)
# Out:
#   Paciente  Oxigênio Medido (%)
# 0       P1                 92.3
# 1       P2                 98.8
# 2       P3                 95.5
# 3       P4                 97.5
# 4       P5                 90.0

# %% [markdown]
# ### 4 - Qual é o valor inteiro mais próximo para cada?

# %%
dados["Oxigênio Medido (%)"] = dados["Oxigênio Medido (%)"].round(0).astype(int)
display(dados)
# Out:
#   Paciente  Oxigênio Medido (%)
# 0       P1                   92
# 1       P2                   99
# 2       P3                   96
# 3       P4                   98
# 4       P5                   90

# %% [markdown]
# ### 5 - Mostre os resultados dentro de uma tabela

# %%
dados["Oxigênio Medido 2casas dec (%)"] = dados["Oxigênio Medido (%)"].round(2)
dados["Oxigênio Medido truncado 1casa dec (%)"] = np.trunc(dados["Oxigênio Medido (%)"] * 10)/10
dados["Oxigênio Medido inteiro mais prox (%)"] = dados["Oxigênio Medido (%)"].round(2).astype(int)
display(dados)
# Out:
#   Paciente  Oxigênio Medido (%)  Oxigênio Medido 2casas dec (%)  \
# 0       P1              92.3456                           92.35
# 1       P2              98.8765                           98.88
# 2       P3              95.5555                           95.56
# 3       P4              97.4999                           97.50
# 4       P5              90.0501                           90.05
#
#    Oxigênio Medido truncado 1casa dec (%)  \
# 0                                    92.3
# 1                                    98.8
# 2                                    95.5
# 3                                    97.4
# 4                                    90.0
#
#    Oxigênio Medido inteiro mais prox (%)
# 0                                     92
# 1                                     98
# 2                                     95
# 3                                     97
# 4                                     90

# %% [markdown]
# <span style="font-size:90%">
#
# **Guia Rápido: Arredondamento e Truncamento**
#
# - Arredondar para n casas decimais: `dados["Comprimento Medido (cm)"].round(0)`
# - Truncar para n casas decimais: `np.trunc(dados["Comprimento Medido (cm)"] * 10) / 10`
# - Arredondar para inteiro mais próximo: `dados["Comprimento Medido (cm)"].round(0).astype(int)`
#
# </span>

# %% [markdown]
# ## Parte Teórica

# %% [markdown]
# **Questão 1.**
#
# Julgue as afirmativas abaixo como V (Verdadeiro) ou F (Falso) e justifique as que forem Falsas.

# %% [markdown]
# 1. F - O erro absoluto nos dá a exata noção do impacto da falha, independentemente da ordem de grandeza do valor medido.
#     - O que dá a real noção do impacto real é o erro relativo, pois o erro absoluto não faz relação com a ordem de grandeza desejada. 1 metro de erro pode ser pouco em relação à uma estrada inteira e muito grande em relação à uma tábua de madeira
# 2. V - O instrumento de medida escolhido para medir uma grandeza deve ser coerente com aquilo que se deseja medir.
#
# 3. F - O erro percentual é *calculated* multiplicando o erro absoluto por 100%.
#     - A equação correta é: $Ep=Er×100%$
#
# 4. V - Erros aleatórios não podem ser eliminados por calibração de instrumentos, mas podem ser minimizados através de repetições e métodos estatísticos (como a média).
#
# 5.  O número de algoritmos significativos de uma grandeza é determinado pela sua incerteza.

# %% [markdown]
# **Resposta:**

# %% [markdown]
# **Questão 2.**
#
# Quando você faz a medição de alguma grandeza, com um instrumento de medição qualquer, em qual conjunto cai a medida que você
# obteve?
#
# Conjunto dos números Naturais, Inteiros, Racionais, Irracionais, Reais ou Complexos? Justifique sua resposta

# %% [markdown]
# **Resposta:**
# Racionais, pois sempre serão números finitos, não sendo possível números irracionais como $\sqrt{2}$ ou $\pi$.
